# %%
import json
import numpy as np
#import pandas as pd
from matplotlib import pyplot as plt
#import seaborn as sns

# %%
#file = ("Finance.xlsx")
#Data = pd.read_excel(file, index_col="Name")
#print(Data)
#
#set = Data.iloc[:2,:]
#
#print(set)

# %%
data = [200,1000,4000,200,123,3,54,32]

label = ['Food','boots','1','2','3','4','5','6']

x = label
y= data

fig = plt.figure(figsize =(10, 7))
plt.pie(y, labels=x)

plt.show()

#sucessfully done the pie chart
